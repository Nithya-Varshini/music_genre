# %% [markdown]
# <a href="https://colab.research.google.com/github/Nithya-Varshini/music_genre/blob/main/music_genre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa.display

# %%
music_data = pd.read_csv('/content/file.csv')
music_data.head(5)
# Out:
#           filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1  blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2  blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3  blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4  blues.00004.wav  661794          0.308526         0.087841  0.091529
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002827             1784.165850          129774.064525
# 1  0.002373             1530.176679          375850.073649
# 2  0.002746             1552.811865          156467.643368
# 3  0.006346             1070.106615          184355.942417
# 4  0.002303             1835.004266          343399.939274
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              2002.449060            85882.761315  ...   52.420910
# 1              2039.036516           213843.755497  ...   55.356403
# 2              1747.702312            76254.192257  ...   40.598766
# 3              1596.412872           166441.494769  ...   44.427753
# 4              1748.172116            88445.209036  ...   86.099236
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0    -1.690215   36.524071    -0.408979   41.597103    -2.303523   55.062923
# 1    -0.731125   60.314529     0.295073   48.120598    -0.283518   51.106190
# 2    -7.729093   47.639427    -1.816407   52.382141    -3.439720   46.639660
# 3    -3.319597   50.206673     0.636965   37.319130    -0.619121   37.259739
# 4    -5.454034   75.269707    -0.916874   53.613918    -4.404827   62.910812
#
#    mfcc20_mean  mfcc20_var  label
# 0     1.221291   46.936035  blues
# 1     0.531217   45.786282  blues
# 2    -2.231258   30.573025  blues
# 3    -3.407448   31.949339  blues
# 4   -11.703234   55.195160  blues
#
# [5 rows x 60 columns]

# %%
music_data['label'].value_counts()
# Out:
# label
# blues        100
# classical    100
# country      100
# disco        100
# hiphop       100
# jazz         100
# metal        100
# pop          100
# reggae       100
# rock         100
# Name: count, dtype: int64

# %%
import numpy as np
import seaborn as sns

# Computing the Correlation Matrix
spike_cols = [col for col in music_data.columns if 'mean' in col]

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(16, 11));

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(music_data[spike_cols].corr(), cmap='YlGn')

plt.title('Heatmap for MEAN variables', fontsize = 20)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10);

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
music_data['label'] = label_encoder.fit_transform(music_data['label'])

# %%
X = music_data.drop(['label','filename'],axis=1)
y = music_data['label']

# %%
cols = X.columns
minmax = preprocessing.MinMaxScaler()
np_scaled = minmax.fit_transform(X)

# new data frame with the new scaled data.
X = pd.DataFrame(np_scaled, columns = cols)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
													test_size=0.3,
													random_state=111)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((700, 58), (300, 58), (700,), (300,))

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.3-cp310-cp310-manylinux2014_x86_64.whl (98.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.3

# %%
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import catboost as cb
from xgboost import XGBClassifier

rf = RandomForestClassifier(n_estimators=1000, max_depth=10, random_state=0)
cbc = cb.CatBoostClassifier(verbose=0, eval_metric='Accuracy', loss_function='MultiClass')
xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05)

for clf in (rf, cbc, xgb):
	clf.fit(X_train, y_train)
	preds = clf.predict(X_test)
	print(clf.__class__.__name__,accuracy_score(y_test, preds))
# Out:
# RandomForestClassifier 0.78
# CatBoostClassifier 0.8333333333333334
# XGBClassifier 0.7833333333333333

# %%
# compile the model
adam = keras.optimizers.Adam(lr=1e-4)
model.compile(optimizer=adam,
			loss="sparse_categorical_crossentropy",
			metrics=["accuracy"])

hist = model.fit(X_train, y_train,
				validation_data = (X_test,y_test),
				epochs = 100,
				batch_size = 32)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 22/22 [==============================] - 2s 16ms/step - loss: 1.9147 - accuracy: 0.3186 - val_loss: 2.1599 - val_accuracy: 0.2600
# Epoch 2/100
# 22/22 [==============================] - 0s 5ms/step - loss: 1.2205 - accuracy: 0.5757 - val_loss: 2.1035 - val_accuracy: 0.2600
# Epoch 3/100
# 22/22 [==============================] - 0s 5ms/step - loss: 1.0480 - accuracy: 0.6457 - val_loss: 2.0335 - val_accuracy: 0.3267
# Epoch 4/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.9366 - accuracy: 0.6914 - val_loss: 1.9508 - val_accuracy: 0.4300
# Epoch 5/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.8139 - accuracy: 0.7200 - val_loss: 1.8713 - val_accuracy: 0.4300
# Epoch 6/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.7437 - accuracy: 0.7529 - val_loss: 1.7601 - val_accuracy: 0.5700
# Epoch 7/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.7088 - accuracy: 0.7629 - val_loss: 1.6806 - val_accuracy: 0.6133
# Epoch 8/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.6412 - accuracy: 0.7843 - val_loss: 1.5798 - val_accuracy: 0.6267
# Epoch 9/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.5829 - accuracy: 0.8057 - val_loss: 1.4804 - val_accuracy: 0.6867
# Epoch 10/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.5862 - accuracy: 0.7900 - val_loss: 1.4073 - val_accuracy: 0.7333
# Epoch 11/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5439 - accuracy: 0.8100 - val_loss: 1.3143 - val_accuracy: 0.7367
# Epoch 12/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5047 - accuracy: 0.8400 - val_loss: 1.2547 - val_accuracy: 0.7333
# Epoch 13/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.4606 - accuracy: 0.8371 - val_loss: 1.1681 - val_accuracy: 0.7367
# Epoch 14/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.4434 - accuracy: 0.8500 - val_loss: 1.0861 - val_accuracy: 0.7233
# Epoch 15/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.4224 - accuracy: 0.8500 - val_loss: 1.0228 - val_accuracy: 0.7667
# Epoch 16/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.4010 - accuracy: 0.8743 - val_loss: 0.9378 - val_accuracy: 0.7733
# Epoch 17/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.4013 - accuracy: 0.8543 - val_loss: 0.9064 - val_accuracy: 0.7800
# Epoch 18/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3802 - accuracy: 0.8686 - val_loss: 0.8564 - val_accuracy: 0.7433
# Epoch 19/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3197 - accuracy: 0.8986 - val_loss: 0.8537 - val_accuracy: 0.7467
# Epoch 20/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3376 - accuracy: 0.8900 - val_loss: 0.8648 - val_accuracy: 0.7267
# Epoch 21/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3027 - accuracy: 0.9057 - val_loss: 0.7927 - val_accuracy: 0.7300
# Epoch 22/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2776 - accuracy: 0.9171 - val_loss: 0.7797 - val_accuracy: 0.7667
# Epoch 23/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2813 - accuracy: 0.8986 - val_loss: 0.7560 - val_accuracy: 0.7667
# Epoch 24/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2858 - accuracy: 0.9171 - val_loss: 0.8102 - val_accuracy: 0.7267
# Epoch 25/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2447 - accuracy: 0.9129 - val_loss: 0.7852 - val_accuracy: 0.7533
# Epoch 26/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2742 - accuracy: 0.9143 - val_loss: 0.7675 - val_accuracy: 0.7767
# Epoch 27/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2354 - accuracy: 0.9371 - val_loss: 0.8584 - val_accuracy: 0.7533
# Epoch 28/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2283 - accuracy: 0.9329 - val_loss: 0.8014 - val_accuracy: 0.7800
# Epoch 29/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2387 - accuracy: 0.9214 - val_loss: 0.7949 - val_accuracy: 0.7800
# Epoch 30/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2187 - accuracy: 0.9357 - val_loss: 0.8975 - val_accuracy: 0.7467
# Epoch 31/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2051 - accuracy: 0.9386 - val_loss: 0.8029 - val_accuracy: 0.7933
# Epoch 32/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1819 - accuracy: 0.9471 - val_loss: 0.8224 - val_accuracy: 0.7767
# Epoch 33/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1741 - accuracy: 0.9514 - val_loss: 0.7920 - val_accuracy: 0.7700
# Epoch 34/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1742 - accuracy: 0.9386 - val_loss: 0.8271 - val_accuracy: 0.7800
# Epoch 35/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1859 - accuracy: 0.9414 - val_loss: 0.9290 - val_accuracy: 0.7500
# Epoch 36/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1745 - accuracy: 0.9443 - val_loss: 0.8846 - val_accuracy: 0.7700
# Epoch 37/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1596 - accuracy: 0.9514 - val_loss: 1.0015 - val_accuracy: 0.7267
# Epoch 38/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1461 - accuracy: 0.9643 - val_loss: 0.8005 - val_accuracy: 0.7733
# Epoch 39/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1638 - accuracy: 0.9471 - val_loss: 0.8183 - val_accuracy: 0.7833
# Epoch 40/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1559 - accuracy: 0.9614 - val_loss: 0.9111 - val_accuracy: 0.7733
# Epoch 41/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1347 - accuracy: 0.9543 - val_loss: 0.8458 - val_accuracy: 0.7800
# Epoch 42/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1502 - accuracy: 0.9529 - val_loss: 0.8728 - val_accuracy: 0.7667
# Epoch 43/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1349 - accuracy: 0.9657 - val_loss: 0.9318 - val_accuracy: 0.7733
# Epoch 44/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1758 - accuracy: 0.9300 - val_loss: 0.9923 - val_accuracy: 0.7667
# Epoch 45/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1589 - accuracy: 0.9471 - val_loss: 0.8291 - val_accuracy: 0.7867
# Epoch 46/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1627 - accuracy: 0.9429 - val_loss: 1.0139 - val_accuracy: 0.7500
# Epoch 47/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1475 - accuracy: 0.9571 - val_loss: 0.9646 - val_accuracy: 0.7633
# Epoch 48/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1072 - accuracy: 0.9714 - val_loss: 1.0652 - val_accuracy: 0.7433
# Epoch 49/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1380 - accuracy: 0.9557 - val_loss: 1.0772 - val_accuracy: 0.7533
# Epoch 50/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1188 - accuracy: 0.9671 - val_loss: 1.1047 - val_accuracy: 0.7133
# Epoch 51/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1236 - accuracy: 0.9629 - val_loss: 1.1343 - val_accuracy: 0.7300
# Epoch 52/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1178 - accuracy: 0.9629 - val_loss: 1.0913 - val_accuracy: 0.7500
# Epoch 53/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1573 - accuracy: 0.9500 - val_loss: 1.0965 - val_accuracy: 0.7467
# Epoch 54/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1747 - accuracy: 0.9429 - val_loss: 0.9704 - val_accuracy: 0.7667
# Epoch 55/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1380 - accuracy: 0.9586 - val_loss: 1.1460 - val_accuracy: 0.7433
# Epoch 56/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1424 - accuracy: 0.9529 - val_loss: 1.1219 - val_accuracy: 0.7367
# Epoch 57/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0824 - accuracy: 0.9814 - val_loss: 1.0774 - val_accuracy: 0.7533
# Epoch 58/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1236 - accuracy: 0.9614 - val_loss: 1.0811 - val_accuracy: 0.7367
# Epoch 59/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1065 - accuracy: 0.9671 - val_loss: 1.0637 - val_accuracy: 0.7667
# Epoch 60/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1042 - accuracy: 0.9700 - val_loss: 1.0712 - val_accuracy: 0.7400
# Epoch 61/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0885 - accuracy: 0.9829 - val_loss: 1.0660 - val_accuracy: 0.7300
# Epoch 62/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1004 - accuracy: 0.9743 - val_loss: 1.1089 - val_accuracy: 0.7467
# Epoch 63/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0907 - accuracy: 0.9771 - val_loss: 1.1299 - val_accuracy: 0.7600
# Epoch 64/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0978 - accuracy: 0.9714 - val_loss: 1.0856 - val_accuracy: 0.7467
# Epoch 65/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0870 - accuracy: 0.9757 - val_loss: 1.1238 - val_accuracy: 0.7367
# Epoch 66/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0849 - accuracy: 0.9771 - val_loss: 1.1815 - val_accuracy: 0.7233
# Epoch 67/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1063 - accuracy: 0.9700 - val_loss: 1.1354 - val_accuracy: 0.7233
# Epoch 68/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0919 - accuracy: 0.9729 - val_loss: 1.0677 - val_accuracy: 0.7733
# Epoch 69/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0857 - accuracy: 0.9729 - val_loss: 1.1024 - val_accuracy: 0.7467
# Epoch 70/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0662 - accuracy: 0.9814 - val_loss: 1.0972 - val_accuracy: 0.7467
# Epoch 71/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0656 - accuracy: 0.9843 - val_loss: 1.2293 - val_accuracy: 0.7233
# Epoch 72/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0783 - accuracy: 0.9786 - val_loss: 1.0478 - val_accuracy: 0.7667
# Epoch 73/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0681 - accuracy: 0.9829 - val_loss: 1.3050 - val_accuracy: 0.7367
# Epoch 74/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0746 - accuracy: 0.9814 - val_loss: 1.1960 - val_accuracy: 0.7533
# Epoch 75/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0645 - accuracy: 0.9857 - val_loss: 1.1002 - val_accuracy: 0.7533
# Epoch 76/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0797 - accuracy: 0.9743 - val_loss: 1.2095 - val_accuracy: 0.7533
# Epoch 77/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0706 - accuracy: 0.9800 - val_loss: 1.2451 - val_accuracy: 0.7133
# Epoch 78/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0792 - accuracy: 0.9743 - val_loss: 1.1332 - val_accuracy: 0.7433
# Epoch 79/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0596 - accuracy: 0.9814 - val_loss: 1.1121 - val_accuracy: 0.7567
# Epoch 80/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0819 - accuracy: 0.9743 - val_loss: 1.0694 - val_accuracy: 0.7700
# Epoch 81/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0833 - accuracy: 0.9771 - val_loss: 1.0090 - val_accuracy: 0.7567
# Epoch 82/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0770 - accuracy: 0.9786 - val_loss: 1.1344 - val_accuracy: 0.7467
# Epoch 83/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0632 - accuracy: 0.9886 - val_loss: 1.0776 - val_accuracy: 0.7667
# Epoch 84/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0485 - accuracy: 0.9900 - val_loss: 1.1300 - val_accuracy: 0.7800
# Epoch 85/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0478 - accuracy: 0.9871 - val_loss: 1.0363 - val_accuracy: 0.7633
# Epoch 86/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0416 - accuracy: 0.9986 - val_loss: 1.1705 - val_accuracy: 0.7600
# Epoch 87/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0654 - accuracy: 0.9814 - val_loss: 1.1731 - val_accuracy: 0.7600
# Epoch 88/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0444 - accuracy: 0.9943 - val_loss: 1.1265 - val_accuracy: 0.7767
# Epoch 89/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0612 - accuracy: 0.9814 - val_loss: 1.2025 - val_accuracy: 0.7467
# Epoch 90/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0588 - accuracy: 0.9886 - val_loss: 1.1840 - val_accuracy: 0.7500
# Epoch 91/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0708 - accuracy: 0.9829 - val_loss: 1.2249 - val_accuracy: 0.7500
# Epoch 92/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0587 - accuracy: 0.9871 - val_loss: 1.3108 - val_accuracy: 0.7267
# Epoch 93/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0537 - accuracy: 0.9871 - val_loss: 1.2010 - val_accuracy: 0.7433
# Epoch 94/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0807 - accuracy: 0.9771 - val_loss: 1.2028 - val_accuracy: 0.7667
# Epoch 95/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0638 - accuracy: 0.9814 - val_loss: 1.5751 - val_accuracy: 0.7067
# Epoch 96/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0863 - accuracy: 0.9757 - val_loss: 1.4372 - val_accuracy: 0.7533
# Epoch 97/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0608 - accuracy: 0.9814 - val_loss: 1.4063 - val_accuracy: 0.7400
# Epoch 98/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0718 - accuracy: 0.9757 - val_loss: 1.3364 - val_accuracy: 0.7467
# Epoch 99/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0523 - accuracy: 0.9914 - val_loss: 1.3657 - val_accuracy: 0.7333
# Epoch 100/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0537 - accuracy: 0.9857 - val_loss: 1.2109 - val_accuracy: 0.7700

# %%
test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
print(f"Test accuracy: {test_accuracy}")
# Out:
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2109 - accuracy: 0.7700
# Test accuracy: 0.7699999809265137

# %%
fig, axs = plt.subplots(2,figsize=(10,10))

# accuracy
axs[0].plot(hist.history["accuracy"], label="train")
axs[0].plot(hist.history["val_accuracy"], label="test")
axs[0].set_ylabel("Accuracy")
axs[0].legend()
axs[0].set_title("Accuracy")

# Error
axs[1].plot(hist.history["loss"], label="train")
axs[1].plot(hist.history["val_loss"], label="test")
axs[1].set_ylabel("Error")
axs[1].legend()
axs[1].set_title("Error")

plt.show()
